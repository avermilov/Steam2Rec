# %%
import requests
import pandas as pd
import ast
import json
import urllib
import tqdm
import os

pd.set_option('display.max_columns', None)

def get_reviews(appid, params):
        url = 'https://store.steampowered.com/appreviews/'
        response = requests.get(url=url + appid, params=params, headers={'User-Agent': 'Mozilla/5.0'})
        if response.status_code != 200 or response.json()["success"] not in [1, "1"]:
            print("LOG: ERROR", response.status_code)
            raise ValueError("Status code != 200 or query unsuccessful.")
        return response.json()
    
def get_n_reviews(appid, n):
    reviews = []
    cursor = '*'
    params = {
            'json' : 1,
            'filter' : 'updated',
            'language' : 'all',
            'day_range' : 365,
            'review_type' : 'all',
            'purchase_type' : 'all',
            }
    total = False
#     with tqdm.tqdm() as pbar:
    while n > 0:
        params['cursor'] = cursor.encode()
        params['num_per_page'] = min(100, n)
        n -= 100

        response = get_reviews(appid, params)
        cursor = response['cursor']
        reviews += response['reviews']
#         pbar.update(len(response['reviews']))

        if not total:
                print("total", response["query_summary"]["total_reviews"])
                total = True

        if response["query_summary"]["num_reviews"] == 0:
            break

    return reviews

# %%
# download https://www.kaggle.com/datasets/fronkongames/steam-games-dataset
# unpack in the same dir as this notebook (should be a 'games.csv' file inside)

# %%
games_df = pd.read_csv("games.csv").sample(frac=1, random_state=42 # DO NOT CHANGE!
                                          ).reset_index(drop=True)
print(games_df.shape)
games_df.head(10)
# Out:
# (76987, 39)
#      AppID                            Name  Release date Estimated owners  \
# 0  1936000             The Infernal Return  Sep 10, 2022            0 - 0
# 1   425210                         Shadwen  May 17, 2016  100000 - 200000
# 2  2151890             Wild Isles Playtest  Sep 14, 2022            0 - 0
# 3   719130                      OVO Smash!  Oct 10, 2017        0 - 20000
# 4   891520                 Tranquil Garden  Sep 18, 2020        0 - 20000
# 5  1448650                   Close Contact   Nov 2, 2020    20000 - 50000
# 6   786570                The Alpha Device  Feb 13, 2018    20000 - 50000
# 7   623920  Chicago 1930 : The Prohibition  Sep 11, 2017   50000 - 100000
# 8  1409180             Of Mice and Moggies  Feb 23, 2021        0 - 20000
# 9   775310               Blood of Patriots  Feb 17, 2018        0 - 20000
#
#    Peak CCU  Required age  Price  DLC count  \
# 0         0             0   6.59          0
# 1         4             0  16.99          0
# 2         0             0   0.00          0
# 3         0             0   5.99          0
# 4         0             0   0.00          0
# 5         0             0   4.99          0
# 6         0             0   0.00          0
# 7         1             0   0.54          0
# 8         1             0   4.99          0
# 9         0             0   4.99          0
#
#                                       About the game  \
# 0  Overview The design of the environment is base...
# 1  Shadwen is a 3rd person stealth-action game wh...
# 2                                                NaN
# 3  What happens when Memory Match meets Deathmatc...
# 4  Can the World save itself? In a serene setting...
# 5  Close Contact is a short (approx 1-1.5 hours),...
# 6  Beyond space, beyond reason... beyond humanity...
# 7  Welcome to Chicago ! The Mafia rules the city....
# 8  Of Mice and Moggies is a smart puzzle game, wh...
# 9  ** Now with Nancy Pelosi ** An evil force, lur...
#
#                                  Supported languages  \
# 0  ['English', 'Simplified Chinese', 'Traditional...
# 1  ['English', 'French', 'Italian', 'German', 'Sp...
# 2                                                 []
# 3  ['English', 'French', 'Italian', 'German', 'Sp...
# 4                                        ['English']
# 5                                        ['English']
# 6                                        ['English']
# 7  ['English', 'French', 'Italian', 'German', 'Sp...
# 8  ['English', 'German', 'Japanese', 'Simplified ...
# 9                                        ['English']
#
#                  Full audio languages  \
# 0  ['English', 'Traditional Chinese']
# 1      ['English', 'Spanish - Spain']
# 2                                  []
# 3                                  []
# 4                                  []
# 5                         ['English']
# 6                         ['English']
# 7      ['English', 'Spanish - Spain']
# 8                                  []
# 9                         ['English']
#
#                                              Reviews  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  “Tranquil Garden could set a new standard and ...
# 5                                                NaN
# 6  “When you find a monolith you’ll discover part...
# 7                                                NaN
# 8  “A wonderfully easy suggestion to go and play,...
# 9                                                NaN
#
#                                         Header image  \
# 0  https://cdn.akamai.steamstatic.com/steam/apps/...
# 1  https://cdn.akamai.steamstatic.com/steam/apps/...
# 2  https://cdn.akamai.steamstatic.com/steam/apps/...
# 3  https://cdn.akamai.steamstatic.com/steam/apps/...
# 4  https://cdn.akamai.steamstatic.com/steam/apps/...
# 5  https://cdn.akamai.steamstatic.com/steam/apps/...
# 6  https://cdn.akamai.steamstatic.com/steam/apps/...
# 7  https://cdn.akamai.steamstatic.com/steam/apps/...
# 8  https://cdn.akamai.steamstatic.com/steam/apps/...
# 9  https://cdn.akamai.steamstatic.com/steam/apps/...
#
#                                        Website  \
# 0             http://knifish.wixsite.com/games
# 1                       http://www.shadwen.com
# 2                                          NaN
# 3     http://www.inprincipleinc.com/games.html
# 4  https://glassrobotgames.com/tranquil-garden
# 5                                          NaN
# 6                    http://xiotex-studios.com
# 7                                          NaN
# 8                                          NaN
# 9                   http://bloodofpatriots.us/
#
#                                   Support url                Support email  \
# 0           https://knifish.wixsite.com/games             knifish@mail.com
# 1  http://www.frozenbyte.com/contact/#Support       support@frozenbyte.com
# 2                                         NaN                          NaN
# 3                                         NaN   support@inprincipleinc.com
# 4                         glassrobotgames.com    GlassRobotGames@Gmail.com
# 5           https://twitter.com/ryanjavanshir  ryanjavanshir@hotmail.co.uk
# 6                   http://xiotex-studios.com     byron@xiotex-studios.com
# 7                                         NaN   support-steam@microids.com
# 8               https://discord.gg/AxYpX7AaFP          rene@bippinbits.com
# 9                  http://bloodofpatriots.us/        josh@12to6studios.com
#
#    Windows    Mac  Linux  Metacritic score  \
# 0     True  False  False                 0
# 1     True   True   True                53
# 2     True  False  False                 0
# 3     True  False  False                 0
# 4     True  False  False                 0
# 5     True  False  False                 0
# 6     True   True  False                 0
# 7     True   True  False                 0
# 8     True   True   True                 0
# 9     True  False  False                 0
#
#                                       Metacritic url  User score  Positive  \
# 0                                                NaN           0         0
# 1  https://www.metacritic.com/game/pc/shadwen?fta...           0       888
# 2                                                NaN           0         0
# 3                                                NaN           0         8
# 4                                                NaN           0         5
# 5                                                NaN           0        13
# 6                                                NaN           0        53
# 7                                                NaN           0        76
# 8                                                NaN           0        28
# 9                                                NaN           0        22
#
#    Negative  Score rank  Achievements  Recommendations  \
# 0         0         NaN             0                0
# 1       280         NaN            48              893
# 2         0         NaN             0                0
# 3         1         NaN            50                0
# 4         1         NaN             0                0
# 5         3         NaN             0                0
# 6        31         NaN             0                0
# 7        38         NaN             0                0
# 8         0         NaN             0                0
# 9         1         NaN             0                0
#
#                                                Notes  \
# 0  You will rarely but not never see some male sk...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
# 8                                                NaN
# 9                                                NaN
#
#    Average playtime forever  Average playtime two weeks  \
# 0                         0                           0
# 1                       411                           0
# 2                         0                           0
# 3                         0                           0
# 4                         0                           0
# 5                         0                           0
# 6                         0                           0
# 7                         3                           0
# 8                         0                           0
# 9                         0                           0
#
#    Median playtime forever  Median playtime two weeks           Developers  \
# 0                        0                          0        Knifish Games
# 1                      613                          0           Frozenbyte
# 2                        0                          0                  NaN
# 3                        0                          0   in Principle Games
# 4                        0                          0          Glass Robot
# 5                        0                          0       Ryan Javanshir
# 6                        0                          0   Xiotex Studios Ltd
# 7                        6                          0           Spellbound
# 8                        0                          0           Bippinbits
# 9                        0                          0  12 to 6 Studios LLC
#
#                           Publishers  \
# 0  Knifish Studio,Angel Star Studios
# 1                         Frozenbyte
# 2                                NaN
# 3                   in Principle Inc
# 4                        Glass Robot
# 5                     Ryan Javanshir
# 6                 Xiotex Studios Ltd
# 7                           Microids
# 8                         Bippinbits
# 9                12 to 6 Studios LLC
#
#                                           Categories  \
# 0              Single-player,Full controller support
# 1  Single-player,Steam Achievements,Full controll...
# 2                                                NaN
# 3  Single-player,Multi-player,PvP,Shared/Split Sc...
# 4           Single-player,Partial Controller Support
# 5                                      Single-player
# 6           Single-player,Partial Controller Support
# 7                                      Single-player
# 8  Single-player,Partial Controller Support,Steam...
# 9  Single-player,Multi-player,PvP,Shared/Split Sc...
#
#                                      Genres  \
# 0             Action,Adventure,RPG,Strategy
# 1                          Action,Adventure
# 2                                       NaN
# 3                              Casual,Indie
# 4       Adventure,Casual,Indie,RPG,Strategy
# 5                    Action,Adventure,Indie
# 6  Action,Adventure,Casual,Indie,Simulation
# 7                                  Strategy
# 8                                     Indie
# 9                       Action,Casual,Indie
#
#                                                 Tags  \
# 0                                                NaN
# 1  Action,Stealth,Adventure,Female Protagonist,As...
# 2                                                NaN
# 3                                       Indie,Casual
# 4                RPG,Indie,Casual,Adventure,Strategy
# 5  Action,Adventure,Horror,Exploration,Survival,F...
# 6  Casual,Adventure,Simulation,Action,Indie,Walki...
# 7               Strategy,Crime,Isometric,Classic,RTS
# 8  Sokoban,Puzzle,Difficult,2D,Cozy,Top-Down,Rela...
# 9                       Action,Indie,Casual,Fighting
#
#                                          Screenshots  \
# 0  https://cdn.akamai.steamstatic.com/steam/apps/...
# 1  https://cdn.akamai.steamstatic.com/steam/apps/...
# 2                                                NaN
# 3  https://cdn.akamai.steamstatic.com/steam/apps/...
# 4  https://cdn.akamai.steamstatic.com/steam/apps/...
# 5  https://cdn.akamai.steamstatic.com/steam/apps/...
# 6  https://cdn.akamai.steamstatic.com/steam/apps/...
# 7  https://cdn.akamai.steamstatic.com/steam/apps/...
# 8  https://cdn.akamai.steamstatic.com/steam/apps/...
# 9  https://cdn.akamai.steamstatic.com/steam/apps/...
#
#                                               Movies
# 0  http://cdn.akamai.steamstatic.com/steam/apps/2...
# 1  http://cdn.akamai.steamstatic.com/steam/apps/2...
# 2                                                NaN
# 3  http://cdn.akamai.steamstatic.com/steam/apps/2...
# 4  http://cdn.akamai.steamstatic.com/steam/apps/2...
# 5  http://cdn.akamai.steamstatic.com/steam/apps/2...
# 6  http://cdn.akamai.steamstatic.com/steam/apps/2...
# 7  http://cdn.akamai.steamstatic.com/steam/apps/2...
# 8  http://cdn.akamai.steamstatic.com/steam/apps/2...
# 9  http://cdn.akamai.steamstatic.com/steam/apps/2...

# %%
DIR = "steam_reviews_v2"
if not os.path.exists(DIR):
    os.mkdir(DIR)

# %%
MAX_REVIEWS_PER_GAME = 1e9 # DO NOT CHANGE!
IDXS = {
    "artemiy_1": (0, 7_000),
    "artemiy_2": (7_000, 14_000),
    "artemiy_3": (14_000, 20_000),
    "artem_1": (20_000, 27_000),
    "artem_2": (27_000, 34_000),
    "artem_3": (34_000, 40_000),
    "arina_1": (40_000, 47_000),
    "arina_2": (47_000, 54_000),
    "arina_3": (54_000, 60_000),
    "assol_1": (60_000, 67_000),
    "assol_2": (67_000, 74_000),
    "assol_3": (74_000, games_df.shape[0])}
START, END = IDXS["artemiy_1"] # your name here
for i, row in games_df.loc[START: END].iterrows():
    break
    try:
        reviews = get_n_reviews(str(row.AppID), n=MAX_REVIEWS_PER_GAME)
        print(len(reviews), row.Name)

        reviews_df = pd.json_normalize(reviews)
        reviews_df.columns = [column.replace(".", "_") for column in reviews_df.columns]
        reviews_df.to_csv(os.path.join(DIR, f"{row.AppID}.csv"), index=False)
    except KeyboardInterrupt:
        print("Stopping.")
        break
    except:
        print("Encountered exception at", row.AppID)
